# %% [markdown]
# #Install External Libraries

# %% [markdown]
# **Purpose**
#
# Installs all required third-party Python libraries needed by the Healthcare Lakehouse solution before executing any pipeline notebooks.
#
# ## Inputs
# None.
#
# ## Outputs
# - Required Python libraries installed.
# - Python runtime restarted.
#
# ## Runtime Estimate
# 1–3 minutes.

# %%
# %pip install xgboost

# %%
dbutils.library.restartPython()
