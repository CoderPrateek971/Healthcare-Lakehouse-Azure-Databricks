# %% [markdown]
# ## Bootstrap Script

# %% [markdown]
# ### This bootstrap script is intended for a new Databricks workspace. Uncomment and execute the SQL below only if the Unity Catalog and required schemas have not already been created.

# %%
# %sql
-- CREATE CATALOG IF NOT EXISTS db_healthcare_kl;

CREATE SCHEMA IF NOT EXISTS db_healthcare_kl.bronze;
CREATE SCHEMA IF NOT EXISTS db_healthcare_kl.silver;
CREATE SCHEMA IF NOT EXISTS db_healthcare_kl.omop;
CREATE SCHEMA IF NOT EXISTS db_healthcare_kl.gold;
